# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
pd = pd.read_html("https://en.wikipedia.org/wiki/2023_Formula_One_World_Championship")
len(pd)
# Out:
# 12

# %%
pd = pd[1]
pd
# Out:
#               Round                Grand Prix  \
# 0                 1        Bahrain Grand Prix
# 1                 2  Saudi Arabian Grand Prix
# 2                 3     Australian Grand Prix
# 3                 4     Azerbaijan Grand Prix
# 4                 5          Miami Grand Prix
# 5                 6         Monaco Grand Prix
# 6                 7        Spanish Grand Prix
# 7                 8       Canadian Grand Prix
# 8                 9       Austrian Grand Prix
# 9                10        British Grand Prix
# 10               11      Hungarian Grand Prix
# 11               12        Belgian Grand Prix
# 12               13          Dutch Grand Prix
# 13               14        Italian Grand Prix
# 14               15      Singapore Grand Prix
# 15               16       Japanese Grand Prix
# 16               17          Qatar Grand Prix
# 17               18  United States Grand Prix
# 18               19    Mexico City Grand Prix
# ...

# %%
pd.to_csv("f1.csv")

# %%
ls
# Out:
# Gulf shopping spree - Sheet1.csv  gulfraw1.svg
# Gulfracing.ipynb                  gulfraw2.svg
# Gulfshopping.csv                  index.html
# atp_matches_2022.csv              soccerjjay.pdf
# club_buy - Google Sheets.html     tennis1.ipynb
# club_buy.csv                      tennis2.ipynb
# f1.csv                            viz1.svg
# flurry.svg                        viz2.svg
# fund1.svg                         wages.svg
# fund2.svg                         wta_matches_2022.csv
# gulf_sports.ipynb                 youtube/
